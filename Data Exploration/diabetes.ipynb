# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Import Dataset
d = pd.read_excel('origDiabetes.xlsx')

# Drop columns that are not part of four descriptive features
df = d.drop(columns=(["BloodPressure", "Age", "Insulin", "DiabetesPedigreeFunction"]), axis = 1)


# Mode of target feature
df3 =df[["Outcome"]].mode()

# Save new datafram to csv file
df.to_csv('modified.csv')

# Create table with features count, mean, std (standard deviation), min, 25% (1st quart.), 50% (median), 75%(3rd quart.), max
df = df[["Pregnancies", "Glucose", "BMI", "SkinThickness"]].describe()

# Only average of Features
# df = df[["Pregnancies", "Glucose", "BMI", "SkinThickness"]].mean()

# Save modified dataset to csv
df.to_csv('modified2.csv')

# Line plots of descriptive features
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.lineplot(x='Pregnancies', y='BMI', hue='Outcome', data=d, ax=ax[0])
sns.lineplot(x='SkinThickness', y='Glucose', hue='Outcome', data=d, ax=ax[1])

fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.lineplot(x='Pregnancies', y='Glucose', hue='Outcome', data=d, ax=ax[0])
sns.lineplot( x='BMI', y='SkinThickness', hue='Outcome', data=d, ax=ax[1])

fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.lineplot(x='Pregnancies', y='SkinThickness', hue='Outcome', data=d, ax=ax[0])
sns.lineplot(x='BMI', y='Glucose', hue='Outcome', data=d, ax=ax[1])


# Display descriptive features data quality report
print(df)
print(df3)
# Out:
#        Pregnancies     Glucose         BMI  SkinThickness
# count   768.000000  768.000000  768.000000     768.000000
# mean      3.845052  120.894531   31.992578      20.536458
# std       3.369578   31.972618    7.884160      15.952218
# min       0.000000    0.000000    0.000000       0.000000
# 25%       1.000000   99.000000   27.300000       0.000000
# 50%       3.000000  117.000000   32.000000      23.000000
# 75%       6.000000  140.250000   36.600000      32.000000
# max      17.000000  199.000000   67.100000      99.000000
#   Outcome
# 0   alive
