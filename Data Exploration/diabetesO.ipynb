# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Import Dataset
d = pd.read_excel('origDiabetes.xlsx')

# Drop columns that are not part of four descriptive features
dfO = d.drop(columns=(["Age", "SkinThickness", "Insulin", "DiabetesPedigreeFunction"]), axis = 1)



# Mode of target feature
dfO3 =dfO[["Outcome"]].mode()

# Save new datafram to csv file
dfO.to_csv('modifiedO.csv')


# Create table with features count, mean, std (standard deviation), min, 25% (1st quart.), 50% (median), 75%(3rd quart.), max
dfO = dfO[["Pregnancies", "BloodPressure", "BMI", "Glucose"]].describe()
# Only average of Features
# dfO = dfO[["Pregnancies", "BloodPressure", "BMI", "Glucose"]].mean()

# Save modified dataset to csv
dfO.to_csv('modifiedO2.csv')

# Line plots of descriptive features
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.lineplot(x='Pregnancies', y='BloodPressure', hue='Outcome', data=d, ax=ax[0])
sns.lineplot(x='BMI', y='Glucose', hue='Outcome', data=d, ax=ax[1])

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.lineplot(x='Pregnancies', y='Glucose', hue='Outcome', data=d, ax=ax[0])
sns.lineplot(x='BMI', y='BloodPressure', hue='Outcome', data=d, ax=ax[1])

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.lineplot(x='Pregnancies', y='BMI', hue='Outcome', data=d, ax=ax[0])
sns.lineplot(x='BloodPressure', y='Glucose', hue='Outcome', data=d, ax=ax[1])

# Display descriptive features data quality report
print(dfO)
print(dfO3)
# Out:
#        Pregnancies  BloodPressure         BMI     Glucose
# count   768.000000     768.000000  768.000000  768.000000
# mean      3.845052      69.105469   31.992578  120.894531
# std       3.369578      19.355807    7.884160   31.972618
# min       0.000000       0.000000    0.000000    0.000000
# 25%       1.000000      62.000000   27.300000   99.000000
# 50%       3.000000      72.000000   32.000000  117.000000
# 75%       6.000000      80.000000   36.600000  140.250000
# max      17.000000     122.000000   67.100000  199.000000
#   Outcome
# 0   alive
